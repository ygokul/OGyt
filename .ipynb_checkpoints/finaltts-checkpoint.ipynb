# %%
from translate import Translator
from gtts import gTTS
import os
import platform
import textwrap
from yt_dlp import YoutubeDL
import assemblyai as aai
def download_audio(url, output_filename):
    try:
        # Ensure the filename has the .mp3 extension
        if not output_filename.endswith('.mp3'):

            ydl_opts = {
                'format': 'bestaudio/best',
                'postprocessors': [{
                    'key': 'FFmpegExtractAudio',
                    'preferredcodec': 'mp3',
                    'preferredquality': '192',
                }],
                'outtmpl': output_filename  # Save as the specified filename
            }
        
        with YoutubeDL(ydl_opts) as ydl:
            ydl.download([url])
        return output_filename+".mp3"
    except Exception as e:
        print("Error:", e)
        return None

def browse_path_or_url():
    while True:
        user_input = input("Enter the URL of the video (or 'exit' to quit): ")
        if user_input.lower() == "exit":
            return None
        elif "http" in user_input:
            return user_input
        else:
            print("Invalid input. Please enter a valid URL.")

def transcribe_audio(file_path):
    try:
        aai.settings.api_key = "8ded3e61ee47493b8d2bcc093ca1bf67"
        transcriber = aai.Transcriber()
        transcript = transcriber.transcribe(file_path)
        return transcript.text
    except Exception as e:
        print("Error during transcription:", e)
        return None

if __name__ == "__main__":
    print("Please enter the URL of the video.")
    print("Type 'exit' to quit.")
    video_input = browse_path_or_url()

    if not video_input:
        print("No input provided. Exiting.")
        exit()

    output_filename = "trans"
    audio_path = download_audio(video_input, output_filename)

    if not audio_path:
        print("Failed to download the audio. Exiting.")
        exit()
    
    print("Audio downloaded successfully at:", audio_path)

    # Transcribe the downloaded audio file
    transcription = transcribe_audio(audio_path)

    if transcription:
        print("Transcription successful,English text:" +transcription)
    else:
        print("Transcription failed.")

available_languages = {
    'Tamil': 'ta',
    'Hindi': 'hi',
    'French': 'fr',
    'Spanish': 'es',
    'German': 'de',
    'Chinese': 'zh-CN',
    'Japanese': 'ja'
}
def translate_text_to_audio(text, target_lang):
    # Step 1: Split text into smaller chunks
    chunk_size = 500  # Limit of characters per request
    chunks = textwrap.wrap(text, chunk_size)
    translated_text = ""

    # Step 2: Translate each chunk and combine results
    translator = Translator(to_lang=target_lang)
    for chunk in chunks:
        translated_chunk = translator.translate(chunk)
        translated_text += translated_chunk + " "
    
    # Step 3: Convert the translated text to speech
    tts = gTTS(text=translated_text, lang=target_lang)
    audio_file = f"translated_audio_{target_lang}.mp3"
    tts.save(audio_file)
    
    # Print the translated text for reference
    print("Translated Text:", translated_text)
    
    # Step 4: Play the audio based on the operating system
    if platform.system() == "Windows":
        os.system(f"start {audio_file}")
    elif platform.system() == "Darwin":  # macOS
        os.system(f"afplay {audio_file}")
    else:  # Linux
        os.system(f"mpg321 {audio_file}")

# Example usage
english_text = transcription  # Replace with transcript.text or any English text

# Prompt user to select a language
print("Available languages:")
for lang_name in available_languages:
    print(f"- {lang_name}")

selected_lang_name = input("Please enter your target language: ")
target_lang = available_languages.get(selected_lang_name.capitalize())

if target_lang:
    translate_text_to_audio(english_text, target_lang)
else:
    print("Invalid language selection.")
# Out:
# Please enter the URL of the video.
# Type 'exit' to quit.
# [youtube] Extracting URL: https://www.youtube.com/shorts/zyjUfUFAeEU
# [youtube] zyjUfUFAeEU: Downloading webpage
# [youtube] zyjUfUFAeEU: Downloading ios player API JSON
# [youtube] zyjUfUFAeEU: Downloading mweb player API JSON
# [youtube] zyjUfUFAeEU: Downloading m3u8 information
# [info] zyjUfUFAeEU: Downloading 1 format(s): 251
# [download] Destination: trans
# [download] 100% of  745.50KiB in 00:00:00 at 1.58MiB/s
# [ExtractAudio] Destination: trans.mp3
# Deleting original file trans (pass -k to keep)
# Audio downloaded successfully at: trans.mp3
# Transcription successful,English text:We were talking about surrendering. Like when I'd gone for thupaki I had 100% surrendered to Murgudas. Like everything he thought, everything he said. I was diligently listening to him. But the interesting part was that I was originally cast as one of the side bad guys. I was not the main Topaki villain. So the gentleman who was playing that character, I think three days before the shoot said that I've got a Hindi movie so I want to do that three days before the shoot. And how lucky am I. So I remember meeting Murugudas that evening. I hadn't met him before. He'd seen my pictures and he had seen a video of mine from Shakti. When I went to his house, he looked at me. He said, I think you are the main villain. So I thought he's joking. Not really. So I didn't realize that the person who was supposed to play the character had left the role. And I couldn't believe it. And I thought maybe I've not understood what he said. And he said, you are the bad guy, right?
# Available languages:
# - Tamil
# - Hindi
# - French
# - Spanish
# - German
# - Chinese
# - Japanese
# Translated Text: நாங்கள் சரணடைவதைப் பற்றி பேசிக்கொண்டிருந்தோம். நான் துபாகிக்குச் சென்றபோது முர்குடாஸிடம் 100% சரணடைந்ததைப் போல. அவன் நினைத்த அனைத்தையும், அவன் சொன்ன அனைத்தையும் போலவே. நான் ஜாக்கிரதையாக அவனுக்குச் செவிகொடுத்தேன். ஆனால் சுவாரஸ்யமான பகுதி என்னவென்றால், நான் முதலில் பக்க கெட்டவர்களில் ஒருவனாக நடிக்கப்பட்டேன். நான் முக்கிய டோபாகி வில்லன் அல்ல. எனவே அந்த கதாபாத்திரத்தில் நடித்த ஜென்டில்மேன், படப்பிடிப்புக்கு மூன்று நாட்களுக்கு முன்பு, எனக்கு ஒரு இந்தி படம் கிடைத்துள்ளது, எனவே படப்பிடிப்புக்கு மூன்று நாட்களுக்கு முன்பு அதைச் செய்ய விரும்புகிறேன் என்று கூறினார். நான் எவ்வளவு அதிர்ஷ்டசாலி. அதனால் நான் அன்று மாலை முருகதாஸை சந்தித்தது நினைவிருக்கிறதா. நான் அவரை இதற்கு முன்பு சந்தித்ததில்லை. அவர் எனது படங்களைப் பார்த்தார், மேலும் அவர் சக்தி என்பவரிடமிருந்து என்னுடைய வீடியோவைப் பார்த்தார். நான் அவரது வீட்டிற்குச் சென்றபோது, அவர் என்னைப் பார்த்தார். அவர் சொன்னார், நீதான் முக்கிய வில்லன் என்று நினைக்கிறேன். எனவே அவர் நகைச்சுவை செய்கிறார் என்று நினைத்தேன். உண்மையில் இல்லை. எனவே கதாபாத்திரத்தில் நடிக்க வேண்டிய நபர் பாத்திரத்தை விட்டு வெளியேறிவிட்டார் என்பதை நான் உணரவில்லை. என்னால் அதை நம்ப முடியவில்லை. அவர் என்ன சொன்னார் என்று எனக்கு புரியவில்லை என்று நினைத்தேன். அவன் சொன்னான், நீ கெட்ட பையன், இல்லையா?
